# %%
# import the library
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# sklearn :: utils
from sklearn.model_selection import train_test_split

# sklearn :: models
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.preprocessing import PolynomialFeatures

# sklearn :: evaluation metrics
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

sns.set_style('whitegrid')

# %% [markdown]
# # Problem definition

# %% [markdown]
# Apply regression models to predict Airbnb prices

# %% [markdown]
# # Load the data

# %%
df_train = pd.read_csv('data/train.csv', parse_dates=['host_since'])
df_test = pd.read_csv('data/test.csv', parse_dates=['host_since'])
print(df_train.shape, df_test.shape)
# Out:
# (51000, 29) (23111, 28)

# %%
df_ref = df_train.copy()

# %% [markdown]
# # Feature Engineering

# %%
print(df_train.columns)
df_train.head()
# Out:
# Index(['id', 'log_price', 'property_type', 'room_type', 'amenities',
#        'accommodates', 'bathrooms', 'bed_type', 'cancellation_policy',
#        'cleaning_fee', 'city', 'description', 'first_review',
#        'host_has_profile_pic', 'host_identity_verified', 'host_response_rate',
#        'host_since', 'instant_bookable', 'last_review', 'latitude',
#        'longitude', 'name', 'neighbourhood', 'number_of_reviews',
#        'review_scores_rating', 'thumbnail_url', 'zipcode', 'bedrooms', 'beds'],
#       dtype='object')
#          id  log_price property_type        room_type  \
# 0  13662370   3.806662         House     Private room
# 1   4765892   4.941642     Apartment  Entire home/apt
# 2  21169968   4.941642     Apartment  Entire home/apt
# 3   7939196   4.867534     Apartment  Entire home/apt
# 4  18161036   3.663562         House     Private room
#
#                                            amenities  accommodates  bathrooms  \
# 0  {TV,Internet,"Wireless Internet","Air conditio...             2        1.5
# 1  {TV,Internet,"Wireless Internet","Air conditio...             2        2.0
# 2  {TV,"Cable TV","Wireless Internet","Air condit...             5        1.0
# 3  {"Cable TV",Internet,"Wireless Internet","Air ...             6        1.0
# 4  {Internet,"Wireless Internet","Air conditionin...             2        1.0
#
#    bed_type cancellation_policy  cleaning_fee  ...   latitude   longitude  \
# 0  Real Bed              strict          True  ...  41.849684  -87.676270
# 1  Real Bed              strict          True  ...  34.068613 -118.246455
# 2  Real Bed            moderate          True  ...  40.701958  -73.917352
# 3  Real Bed              strict          True  ...  40.742959  -73.990820
# 4  Real Bed            flexible          True  ...  34.046473 -117.734095
#
#                                              name      neighbourhood  \
# 0               Pilsen Arts Community Custom Home             Pilsen
# 1  Apartment 5 minutes from DTLA & Dodger Stadium          Echo Park
# 2  Brand New Huge 2bdr apartment(L,M train 2 min)           Bushwick
# 3                      Grande Super Large APT !!!  Flatiron District
# 4          Private Cozy and Clean Rooms in Pomona                NaN
#
#   number_of_reviews review_scores_rating  \
# 0                17                 97.0
# 1                 2                100.0
# 2                25                 88.0
# 3                12                 82.0
# 4                 2                100.0
#
#                                        thumbnail_url zipcode bedrooms  beds
# 0  https://a0.muscache.com/im/pictures/81318153/a...   60608      1.0   1.0
# 1  https://a0.muscache.com/im/pictures/aa00250e-0...   90012      1.0   1.0
# 2  https://a0.muscache.com/im/pictures/d9220535-c...   11237      2.0   3.0
# 3                                                NaN   10010      1.0   3.0
# 4  https://a0.muscache.com/im/pictures/e0c9b2f9-a...   91766      1.0   1.0
#
# [5 rows x 29 columns]

# %%
df_train.loc[:,'city':'latitude'].head()
# Out:
#       city                                        description first_review  \
# 0  Chicago  CLOSE TO EVERYTHING VIA PUBLIC Love arts & cul...   2015-05-25
# 1       LA  Bright and spacious apartment located in a qui...   2015-11-09
# 2      NYC  New huge 2bdr apartment. Bushwick area. 2 min ...   2017-05-15
# 3      NYC  Hello travelers!!! SO my apt is located in Che...   2012-11-12
# 4       LA  Very cozy, clean, safe and quite single house ...   2017-02-17
#
#   host_has_profile_pic host_identity_verified host_response_rate host_since  \
# 0                    t                      t               100% 2015-05-20
# 1                    t                      t               100% 2015-09-08
# 2                    t                      t               100% 2017-05-06
# 3                    t                      t                70% 2009-02-06
# 4                    t                      t               100% 2015-10-20
#
#   instant_bookable last_review   latitude
# 0                t  2017-01-01  41.849684
# 1                f  2015-11-15  34.068613
# 2                t  2017-09-25  40.701958
# 3                f  2017-07-29  40.742959
# 4                f  2017-03-25  34.046473

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51000 entries, 0 to 50999
# Data columns (total 29 columns):
# id                        51000 non-null int64
# log_price                 51000 non-null float64
# property_type             51000 non-null object
# room_type                 51000 non-null object
# amenities                 51000 non-null object
# accommodates              51000 non-null int64
# bathrooms                 50867 non-null float64
# bed_type                  51000 non-null object
# cancellation_policy       51000 non-null object
# cleaning_fee              51000 non-null bool
# city                      51000 non-null object
# description               51000 non-null object
# first_review              40144 non-null object
# host_has_profile_pic      50873 non-null object
# host_identity_verified    50873 non-null object
# host_response_rate        38449 non-null object
# host_since                50873 non-null datetime64[ns]
# instant_bookable          51000 non-null object
# last_review               40174 non-null object
# latitude                  51000 non-null float64
# longitude                 51000 non-null float64
# name                      51000 non-null object
# neighbourhood             46325 non-null object
# number_of_reviews         51000 non-null int64
# review_scores_rating      39550 non-null float64
# thumbnail_url             45371 non-null object
# zipcode                   50355 non-null object
# bedrooms                  50937 non-null float64
# beds                      50915 non-null float64
# dtypes: bool(1), datetime64[ns](1), float64(7), int64(3), object(17)
# memory usage: 10.9+ MB

# %%
df_train.describe(include='all')
# Out:
#                   id     log_price property_type        room_type amenities  \
# count   5.100000e+04  51000.000000         51000            51000     51000
# unique           NaN           NaN            33                3     47087
# top              NaN           NaN     Apartment  Entire home/apt        {}
# freq             NaN           NaN         33676            28367       397
# first            NaN           NaN           NaN              NaN       NaN
# last             NaN           NaN           NaN              NaN       NaN
# mean    1.127396e+07      4.778693           NaN              NaN       NaN
# std     6.071084e+06      0.714838           NaN              NaN       NaN
# min     3.440000e+02      0.000000           NaN              NaN       NaN
# 25%     6.311556e+06      4.304065           NaN              NaN       NaN
# 50%     1.226652e+07      4.700480           NaN              NaN       NaN
# 75%     1.639201e+07      5.216291           NaN              NaN       NaN
# max     2.123090e+07      7.600402           NaN              NaN       NaN
#
#         accommodates     bathrooms  bed_type cancellation_policy cleaning_fee  \
# count   51000.000000  50867.000000     51000               51000        51000
# unique           NaN           NaN         5                   5            2
# top              NaN           NaN  Real Bed              strict         True
# freq             NaN           NaN     49537               22293        37451
# first            NaN           NaN       NaN                 NaN          NaN
# last             NaN           NaN       NaN                 NaN          NaN
# mean        3.153725      1.232420       NaN                 NaN          NaN
# std         2.165303      0.578569       NaN                 NaN          NaN
# min         1.000000      0.000000       NaN                 NaN          NaN
# 25%         2.000000      1.000000       NaN                 NaN          NaN
# 50%         2.000000      1.000000       NaN                 NaN          NaN
# 75%         4.000000      1.000000       NaN                 NaN          NaN
# max        16.000000      8.000000       NaN                 NaN          NaN
#
#         ...      latitude     longitude  \
# count   ...  51000.000000  51000.000000
# unique  ...           NaN           NaN
# top     ...           NaN           NaN
# freq    ...           NaN           NaN
# first   ...           NaN           NaN
# last    ...           NaN           NaN
# mean    ...     38.452159    -92.404169
# std     ...      3.077453     21.708577
# min     ...     33.338905   -122.510940
# 25%     ...     34.128569   -118.342521
# 50%     ...     40.662147    -76.996983
# 75%     ...     40.746418    -73.954359
# max     ...     42.390248    -70.985047
#
#                                           name neighbourhood  \
# count                                    51000         46325
# unique                                   50607           597
# top     Bunk bed in the Treat Street Clubhouse  Williamsburg
# freq                                         6          1942
# first                                      NaN           NaN
# last                                       NaN           NaN
# mean                                       NaN           NaN
# std                                        NaN           NaN
# min                                        NaN           NaN
# 25%                                        NaN           NaN
# 50%                                        NaN           NaN
# 75%                                        NaN           NaN
# max                                        NaN           NaN
#
#        number_of_reviews review_scores_rating  \
# count       51000.000000         39550.000000
# unique               NaN                  NaN
# top                  NaN                  NaN
# freq                 NaN                  NaN
# first                NaN                  NaN
# last                 NaN                  NaN
# mean           21.010157            94.036359
# std            38.073839             7.922591
# min             0.000000            20.000000
# 25%             1.000000            92.000000
# 50%             6.000000            96.000000
# 75%            24.000000           100.000000
# max           605.000000           100.000000
#
#                                             thumbnail_url  zipcode  \
# count                                               45371    50355
# unique                                              45364      732
# top     https://a0.muscache.com/im/pictures/28563531/1...  11211.0
# freq                                                    2      927
# first                                                 NaN      NaN
# last                                                  NaN      NaN
# mean                                                  NaN      NaN
# std                                                   NaN      NaN
# min                                                   NaN      NaN
# 25%                                                   NaN      NaN
# 50%                                                   NaN      NaN
# 75%                                                   NaN      NaN
# max                                                   NaN      NaN
#
#             bedrooms          beds
# count   50937.000000  50915.000000
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# first            NaN           NaN
# last             NaN           NaN
# mean        1.265642      1.709084
# std         0.856894      1.253278
# min         0.000000      0.000000
# 25%         1.000000      1.000000
# 50%         1.000000      1.000000
# 75%         1.000000      2.000000
# max        10.000000     16.000000
#
# [13 rows x 29 columns]

# %%
# drop probable outliers/errors
df_train = df_train.drop(df_train[df_train['log_price']==0].index)
df_train = df_train.drop(df_train[(df_train['accommodates']<=6) & (df_train['beds']>=16)].index)

# %%
# compute correlation
df_corr = df_train.corr()

corrmat = df_corr
f, ax = plt.subplots()
sns.heatmap(corrmat, vmax=.8, square=True)

plt.show()

# %%
df_train['property_type'].value_counts()
# Out:
# Apartment             33676
# House                 11416
# Condominium            1811
# Townhouse              1199
# Loft                    859
# Other                   417
# Guesthouse              329
# Bed & Breakfast         309
# Bungalow                243
# Villa                   122
# Dorm                     97
# Guest suite              83
# Camper/RV                63
# Cabin                    56
# Boutique hotel           53
# Timeshare                52
# Hostel                   49
# In-law                   47
# Boat                     45
# Serviced apartment       16
# Castle                   10
# Tent                      9
# Vacation home             7
# Yurt                      6
# Treehouse                 5
# Hut                       4
# Earth House               4
# Chalet                    2
# Cave                      2
# Tipi                      2
# Lighthouse                1
# Train                     1
# Island                    1
# Name: property_type, dtype: int64

# %%
df_train.groupby(['property_type'])['log_price'].describe().sort_values(by='mean', ascending=False)
# Out:
#                       count      mean       std       min       25%       50%  \
# property_type
# Lighthouse              1.0  5.521461       NaN  5.521461  5.521461  5.521461
# Timeshare              52.0  5.509210  0.517819  4.174387  5.298317  5.517453
# Castle                 10.0  5.301899  0.457953  4.700480  4.985209  5.229045
# Earth House             4.0  5.285391  1.249856  4.174387  4.375585  5.029711
# Tipi                    2.0  5.258999  1.121599  4.465908  4.862453  5.258999
# Boat                   45.0  5.231895  0.738663  4.174387  4.605170  5.247024
# Serviced apartment     16.0  5.175853  0.668443  4.595120  4.676653  5.035030
# Train                   1.0  5.135798       NaN  5.135798  5.135798  5.135798
# Vacation home           7.0  5.102172  0.546727  4.488636  4.866794  4.941642
# Villa                 122.0  5.081168  1.262157  3.178054  4.064717  4.787492
# Condominium          1811.0  5.034120  0.741999  2.639057  4.543295  5.010635
# Island                  1.0  5.010635       NaN  5.010635  5.010635  5.010635
# Boutique hotel         53.0  5.000182  0.511596  4.077537  4.691348  5.003946
# Loft                  859.0  4.992789  0.745677  3.178054  4.499810  4.934474
# Yurt                    6.0  4.951035  0.523680  4.553877  4.597632  4.700480
# Other                 417.0  4.929868  0.819886  2.890372  4.369448  4.828314
# Cave                    2.0  4.909373  0.114635  4.828314  4.868843  4.909373
# Townhouse            1199.0  4.832336  0.789071  2.302585  4.248495  4.691348
# Bungalow              243.0  4.794144  0.494083  3.367296  4.537947  4.779123
# House               11416.0  4.792254  0.872190  2.302585  4.174387  4.605170
# In-law                 47.0  4.776665  0.477031  3.218876  4.494223  4.828314
# Apartment           33676.0  4.756179  0.639001  2.302585  4.317488  4.718499
# Chalet                  2.0  4.755222  0.361208  4.499810  4.627516  4.755222
# Guest suite            83.0  4.751794  0.503434  3.637586  4.459994  4.700480
# Guesthouse            329.0  4.669058  0.477593  3.218876  4.382027  4.615121
# Cabin                  56.0  4.610905  0.520795  3.663562  4.317488  4.553877
# Bed & Breakfast       309.0  4.562276  0.611657  2.995732  4.174387  4.553877
# Camper/RV              63.0  4.558318  0.746806  2.833213  4.085941  4.488636
# Tent                    9.0  4.268997  0.641987  3.663562  3.737670  3.912023
# Treehouse               5.0  4.169936  0.564713  3.218876  4.094345  4.442651
# Hut                     4.0  3.799072  0.906448  2.484907  3.555244  4.134366
# Dorm                   97.0  3.760233  0.524823  2.708050  3.367296  3.806662
# Hostel                 49.0  3.607724  0.724019  2.708050  2.708050  3.465736
#
#                          75%       max
# property_type
# Lighthouse          5.521461  5.521461
# Timeshare           5.701278  6.683361
# Castle              5.421219  6.131226
# Earth House         5.939517  6.907755
# Tipi                5.655544  6.052089
# Boat                5.556828  7.130899
# Serviced apartment  5.399246  7.090077
# Train               5.135798  5.135798
# Vacation home       5.168365  6.214608
# Villa               5.988961  7.598399
# Condominium         5.521461  7.466799
# Island              5.010635  5.010635
# Boutique hotel      5.164786  6.984716
# Loft                5.424911  7.313220
# Yurt                5.172686  5.857933
# Other               5.342334  7.549609
# Cave                4.949903  4.990433
# Townhouse           5.298317  7.467371
# Bungalow            5.010635  6.767343
# House               5.327876  7.600402
# In-law              5.010635  5.768321
# Apartment           5.164786  7.600402
# Chalet              4.882929  5.010635
# Guest suite         5.007291  6.437752
# Guesthouse          4.934474  7.313220
# Cabin               5.005619  5.783825
# Bed & Breakfast     4.890349  6.907755
# Camper/RV           5.010635  6.396930
# Tent                4.905275  5.164786
# Treehouse           4.488636  4.605170
# Hut                 4.378194  4.442651
# Dorm                4.007333  5.293305
# Hostel              4.248495  4.969813

# %%
# reduce dimensions of property type based on type/mean price

properties_group = {'Apartment':['Loft'],
         'House':['Townhouse', 'Bungalow'],
         'Cheap':['Dorm','Hostel','Hut','Treehouse'],
         'Moderate':['Cabin','Camper/RV','Tent','Bed & Breakfast','Chalet','Guesthouse','Guest suite','In-law'],
         'Pricey':['Serviced apartment','Vacation home','Villa','Condominium','Boutique hotel'],
         'Other_expensive':['Lighthouse', 'Timeshare','Castle','Earth House','Tipi','Boat','Train','Island'],
         'Other':['Yurt','Cave']           
        }
new_properties = {i : k for k, v in properties_group.items() for i in v}
df_train['property_type']=df_train['property_type'].replace(new_properties)
df_test['property_type']=df_test['property_type'].replace(new_properties)

# %%
# create one hot encoding of categoricals

# create one hot encoding of property type
df_property = pd.get_dummies(df_train['property_type'])
# apply to test data
df_property_test = pd.get_dummies(df_test['property_type'])

# create one hot encoding of room type
df_room = pd.get_dummies(df_train['room_type'])
df_room_test = pd.get_dummies(df_test['room_type'])

# create one hot encoding of city
df_city = pd.get_dummies(df_train['city'])
df_city_test = pd.get_dummies(df_test['city'])

# create one hot encoding of cancellation policy
df_cancel = pd.get_dummies(df_train['cancellation_policy'])
df_cancel_test = pd.get_dummies(df_test['cancellation_policy'])

# %%
# turn host identity verified into boolean
df_train['host_identity_verified'] = df_train['host_identity_verified'] == 't'
df_test['host_identity_verified'] = df_test['host_identity_verified'] == 't'

# turn instant bookable into boolean
df_train['instant_bookable'] = df_train['instant_bookable'] == 't'
df_test['instant_bookable'] = df_test['instant_bookable'] == 't'

# turn host response rate into numeric
df_train['host_response_rate']=df_train['host_response_rate'].str.replace('%','').astype('float')
df_test['host_response_rate']=df_test['host_response_rate'].str.replace('%','').astype('float')

# %%
# turn host_since date into integer (days since today)
df_train['host_since_days'] = (pd.datetime.today()-df_train['host_since']).dt.days
df_test['host_since_days'] = (pd.datetime.today()-df_test['host_since']).dt.days

# %%
# fill missing items from beds, bedrooms and bathrooms with most frequent
df_train['beds']=df_train['beds'].fillna(df_train['beds'].mode())
df_test['beds']=df_test['beds'].fillna(df_test['beds'].mode())

df_train['bedrooms']=df_train['bedrooms'].fillna(df_train['bedrooms'].mode())
df_test['bedrooms']=df_test['bedrooms'].fillna(df_test['bedrooms'].mode())

df_train['bathrooms']=df_train['bathrooms'].fillna(df_train['bathrooms'].mode())
df_test['bathrooms']=df_test['bathrooms'].fillna(df_test['bathrooms'].mode())

# fill missing items from review scores rating with median (because generally high ratings)
df_train['review_scores_rating']=df_train['review_scores_rating'].fillna(df_train['review_scores_rating'].median())
df_test['review_scores_rating']=df_test['review_scores_rating'].fillna(df_test['review_scores_rating'].median())

# %%
# create feature: total amenities
df_train['total_amenities'] = df_train['amenities'].str.split(',').str.len()
df_test['total_amenities'] = df_test['amenities'].str.split(',').str.len()

# create feature: review_scores_rating * number_of_reviews (places more weight on having a good score based many reviews vs a good score with 1 review)
df_train['review_scores*number'] = df_train['review_scores_rating']*df_train['number_of_reviews']
df_test['review_scores*number'] = df_test['review_scores_rating']*df_test['number_of_reviews']

# create feature: beds * bathrooms * bedrooms (places more weight on having more of all three)
df_train['beds*bath*rooms'] = df_train['beds']*df_train['bedrooms']*df_train['bathrooms']
df_test['beds*bath*rooms'] = df_test['beds']*df_test['bedrooms']*df_test['bathrooms']

# %%
# round lat and long for larger grouping by area
df_train['latitude'] = df_train['latitude'].round(4)
df_train['longitude'] = df_train['longitude'].round(4)

df_test['latitude'] = df_test['latitude'].round(4)
df_test['longitude'] = df_test['longitude'].round(4)

# create feature combinations of latitude and longitude - only a few cities so hopefully this will create distinct areas within cities
df_train['lat+long']=df_train['latitude']+df_train['longitude']
df_test['lat+long']=df_test['latitude']+df_test['longitude']

df_train['lat*long']=df_train['latitude']*df_train['longitude']
df_test['lat*long']=df_test['latitude']*df_test['longitude']

# %%
# merge the dataframes
df_train = pd.concat([df_train, df_property, df_room, df_city, df_cancel], axis=1)
df_test = pd.concat([df_test, df_property_test, df_room_test, df_city_test, df_cancel_test], axis=1)

# %%
# select the columns

# create lists of one-hot encoded columns
properties_list = list(df_property.columns)
room_list = list(df_room.columns)
city_list = list(df_city.columns)
cancel_list = list(df_cancel.columns)

X_columns = ['accommodates', 'bathrooms', 'bedrooms', 'beds', 'total_amenities','review_scores_rating', 'number_of_reviews','latitude','longitude', 'review_scores*number', 'beds*bath*rooms', 'cleaning_fee', 'instant_bookable', 'host_response_rate', 'host_identity_verified', 'host_since_days', 'lat*long', 'lat+long'] + room_list + city_list + properties_list + cancel_list
y_column = ['log_price']

# %%
# handle missing values
df_train = df_train[X_columns + y_column]
print(df_train.shape)
df_train = df_train.fillna(0.0)
print(df_train.shape)

df_test = df_test.fillna(0.0)
# Out:
# (50996, 40)
# (50996, 40)

# %% [markdown]
# # Model Training

# %%
# split the data using sklearn

threshold = 0.8
X = df_train[X_columns]
y = df_train[y_column]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1.0-threshold, shuffle=True)

print('X_train', X_train.shape)
print('y_train', y_train.shape)
print('X_test', X_test.shape)
print('y_test', y_test.shape)
# Out:
# X_train (40796, 39)
# y_train (40796, 1)
# X_test (10200, 39)
# y_test (10200, 1)

# %%
# train a random forest regression
model = RandomForestRegressor(200)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
# Out:
# C:\Users\Kirsten\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # Model Evaluation

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print('RMSE', round(rmse, 3))
plt.scatter(y_test, y_pred, alpha=0.3)
plt.plot(range(0,10), range(0,10), '--r', alpha=0.3, label='Line1')
plt.title('Random Forest Regression')
plt.xlabel('True Value')
plt.ylabel('Predict Value')
plt.show()
# Out:
# RMSE 0.392

# %%
#for i in range(len(X_test.columns)):
fi = []
for i, col in enumerate(X_test.columns):
    fi.append([col, model.feature_importances_[i]])
pd.DataFrame(fi).sort_values(1, ascending=False)
# Out:
#                          0         1
# 18         Entire home/apt  0.362504
# 10         beds*bath*rooms  0.078873
# 16                lat*long  0.075099
# 17                lat+long  0.065389
# 8                longitude  0.062469
# 1                bathrooms  0.057517
# 7                 latitude  0.055885
# 15         host_since_days  0.040676
# 4          total_amenities  0.033265
# 0             accommodates  0.031879
# 9     review_scores*number  0.024958
# 5     review_scores_rating  0.016068
# 6        number_of_reviews  0.014416
# 13      host_response_rate  0.014377
# 2                 bedrooms  0.012556
# 19            Private room  0.008718
# 11            cleaning_fee  0.005550
# 3                     beds  0.005159
# 12        instant_bookable  0.004284
# 14  host_identity_verified  0.004112
# 27               Apartment  0.003923
# 34                flexible  0.003730
# 36                  strict  0.003454
# 35                moderate  0.003087
# 29                   House  0.002905
# 33                  Pricey  0.001989
# 20             Shared room  0.001643
# 31                   Other  0.001419
# 30                Moderate  0.001056
# 23                      DC  0.001032
# 22                 Chicago  0.000555
# 25                     NYC  0.000501
# 32         Other_expensive  0.000299
# 28                   Cheap  0.000231
# 24                      LA  0.000144
# 37         super_strict_30  0.000097
# 26                      SF  0.000073
# 21                  Boston  0.000063
# 38         super_strict_60  0.000046

# %%
# model with more data
model = RandomForestRegressor(200)
model.fit(X, y)
# y_pred = model.predict(X_test)
print(X.shape)
print(y.shape)
# Out:
# C:\Users\Kirsten\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# (50996, 39)
# (50996, 1)

# %%
df_error = pd.DataFrame(X_test).copy()
df_error['log_price'] = y_test
df_error['prediction'] = y_pred
df_error['abs_error'] = abs(df_error['log_price']-df_error['prediction'])
df_error.sort_values(by='abs_error', ascending=False)
# Out:
#        accommodates  bathrooms  bedrooms  beds  total_amenities  \
# 46744             2        1.0       0.0   1.0               14
# 4425              1        0.5       0.0   1.0                1
# 49026             1        1.5       1.0   1.0                7
# 23352             1        1.0       1.0   1.0                9
# 16430             1        1.0       1.0   1.0               17
# 6981              4        1.0       2.0   2.0               43
# 48502             2        1.0       1.0   1.0               15
# 44734             2        1.0       1.0   1.0               14
# 11743             2        1.0       1.0   1.0               10
# 22632             1        1.0       1.0   1.0                1
# 25312             1        1.0       1.0   1.0               13
# 29699             2        1.0       0.0   1.0               12
# 1461              2        1.0       1.0   1.0               11
# 27576             2        1.0       1.0   1.0               18
# 46085             5        2.5       2.0   2.0               23
# 24832             2        1.0       1.0   1.0               14
# 40791             1        1.0       1.0   1.0               13
# 19755             1        1.0       1.0   1.0               15
# 8290              1        1.0       1.0   1.0               30
# 16991             2        1.0       1.0   1.0               10
# 26731             5        1.0       2.0   3.0               18
# 20656             2        1.0       1.0   1.0               17
# 30272             2        1.0       1.0   1.0                5
# 50532             2        1.0       1.0   1.0                9
# 34226             1        1.0       1.0   1.0                4
# 40593            10        2.0       3.0   9.0               18
# 9484              2        1.0       1.0   1.0               17
# 874               1        1.0       1.0   1.0               15
# 2230              8        2.0       3.0   3.0               21
# 17372             2        1.0       1.0   2.0                9
# ...             ...        ...       ...   ...              ...
# 7666              2        1.0       0.0   1.0               17
# 17318             6        1.0       1.0   2.0               24
# 26328             2        1.0       1.0   1.0               27
# 1197              1        0.5       1.0   2.0               13
# 15764             2        1.0       1.0   1.0               11
# 18776             5        1.0       1.0   2.0               19
# 8000              5        1.0       2.0   2.0               22
# 8374              2        1.0       0.0   1.0                9
# 39319             2        1.0       1.0   1.0               13
# 16815             4        3.0       2.0   2.0               18
# 7805              3        1.0       2.0   2.0               19
# 23636             1        2.0       1.0   1.0               11
# 3591              2        1.0       1.0   1.0               39
# 39099             1        1.5       1.0   1.0               19
# 33753             6        2.0       3.0   3.0               20
# 29311             5        1.0       1.0   3.0               26
# 33421             1        2.0       1.0   1.0               18
# 39304             2        1.0       1.0   1.0                7
# 14034             3        1.0       1.0   2.0               20
# 28629             2        1.0       1.0   1.0               16
# 27992             2        1.0       1.0   1.0               17
# 6948              2        1.0       1.0   1.0                8
# 46943             1        1.0       1.0   1.0               17
# 12111             2        1.0       1.0   1.0               24
# 8053              5        1.0       1.0   2.0               27
# 43112             2        1.0       2.0   1.0               12
# 23031             2        1.0       1.0   1.0               14
# 46956             4        1.0       0.0   2.0               23
# 7096              6        1.0       1.0   1.0               23
# 16484             2        1.0       1.0   2.0               23
#
#        review_scores_rating  number_of_reviews  latitude  longitude  \
# 46744                  96.0                  0   38.9016   -77.0352
# 4425                   96.0                  0   37.7775  -122.4095
# 49026                  96.0                  0   34.0847  -118.2884
# 23352                  96.0                  0   40.6942   -73.9931
# 16430                  96.0                  0   40.7118   -73.9492
# 6981                   80.0                  1   40.7322   -73.9527
# 48502                 100.0                  1   40.7684   -73.9557
# 44734                 100.0                  1   37.7828  -122.3905
# 11743                  85.0                 20   40.7282   -73.9893
# 22632                  96.0                  0   40.6770   -73.9551
# 25312                  96.0                  0   42.3324   -71.1073
# 29699                 100.0                  5   38.9014   -77.0471
# 1461                   96.0                  0   34.0781  -118.2681
# 27576                  96.0                  0   34.1573  -118.6007
# 46085                  96.0                 16   34.1035  -118.3051
# 24832                  96.0                  0   40.7827   -73.9768
# 40791                  96.0                  0   37.7681  -122.4358
# 19755                  96.0                  1   40.7224   -73.9982
# 8290                   96.0                  0   34.0667  -118.3963
# 16991                  96.0                  0   34.1487  -118.1403
# 26731                  96.0                  0   38.9005   -76.9904
# 20656                  96.0                 33   41.9133   -87.6529
# 30272                  98.0                 24   37.7828  -122.4465
# 50532                  96.0                  0   38.8559   -76.9626
# 34226                  96.0                  0   34.1998  -118.4492
# 40593                  90.0                  4   34.0732  -118.2780
# 9484                   96.0                  1   40.6413   -73.9030
# 874                    96.0                  0   38.9350   -77.0388
# 2230                  100.0                  2   38.9164   -77.0070
# 17372                  93.0                 15   40.7487   -73.9952
# ...                     ...                ...       ...        ...
# 7666                   99.0                 82   33.9889  -118.4516
# 17318                 100.0                 16   40.7530   -73.9134
# 26328                  96.0                 12   34.0991  -117.7215
# 1197                   96.0                  0   34.0338  -118.2871
# 15764                  91.0                 26   40.7549   -73.9227
# 18776                  99.0                 19   37.7621  -122.4323
# 8000                   93.0                  8   40.6299   -73.9064
# 8374                  100.0                 11   34.0918  -118.2794
# 39319                 100.0                  1   40.6519   -73.9641
# 16815                  97.0                  7   37.7452  -122.4134
# 7805                   97.0                  6   34.0923  -118.3332
# 23636                  94.0                118   40.7579   -73.9268
# 3591                   96.0                  0   41.9103   -87.6341
# 39099                  96.0                 22   40.7305   -73.8533
# 33753                  94.0                 19   34.1774  -118.1252
# 29311                  96.0                 10   34.1026  -118.3304
# 33421                  96.0                  5   40.7167   -73.9526
# 39304                  96.0                  0   40.8508   -73.9332
# 14034                  97.0                449   37.7562  -122.4155
# 28629                  91.0                 20   37.7295  -122.4009
# 27992                 100.0                 26   37.7203  -122.4578
# 6948                   76.0                 36   40.6905   -73.9505
# 46943                  84.0                 28   38.9134   -77.0092
# 12111                  99.0                 27   40.6725   -73.9442
# 8053                   99.0                114   34.0850  -118.2212
# 43112                 100.0                  2   40.7717   -73.9570
# 23031                  94.0                 84   40.6623   -73.9630
# 46956                  84.0                105   37.8078  -122.4167
# 7096                   99.0                 17   40.7117   -74.0083
# 16484                 100.0                  3   41.9890   -87.6640
#
#        review_scores*number  ...  Other_expensive  Pricey  flexible  moderate  \
# 46744                   0.0  ...                0       0         1         0
# 4425                    0.0  ...                0       0         1         0
# 49026                   0.0  ...                0       0         1         0
# 23352                   0.0  ...                0       0         0         0
# 16430                   0.0  ...                0       0         0         0
# 6981                   80.0  ...                0       0         0         0
# 48502                 100.0  ...                0       0         0         1
# 44734                 100.0  ...                0       0         1         0
# 11743                1700.0  ...                0       0         0         1
# 22632                   0.0  ...                0       0         1         0
# 25312                   0.0  ...                0       0         1         0
# 29699                 500.0  ...                0       0         0         1
# 1461                    0.0  ...                0       0         1         0
# 27576                   0.0  ...                0       0         1         0
# 46085                1536.0  ...                0       1         1         0
# 24832                   0.0  ...                0       0         1         0
# 40791                   0.0  ...                0       0         1         0
# 19755                  96.0  ...                0       0         1         0
# 8290                    0.0  ...                0       0         0         0
# 16991                   0.0  ...                0       0         1         0
# 26731                   0.0  ...                0       0         1         0
# 20656                3168.0  ...                0       0         0         1
# 30272                2352.0  ...                0       0         1         0
# 50532                   0.0  ...                0       0         1         0
# 34226                   0.0  ...                0       0         1         0
# 40593                 360.0  ...                0       0         0         0
# 9484                   96.0  ...                0       0         0         0
# 874                     0.0  ...                0       0         0         0
# 2230                  200.0  ...                0       0         1         0
# 17372                1395.0  ...                0       0         0         0
# ...                     ...  ...              ...     ...       ...       ...
# 7666                 8118.0  ...                0       0         0         1
# 17318                1600.0  ...                0       0         0         0
# 26328                1152.0  ...                0       0         1         0
# 1197                    0.0  ...                0       0         1         0
# 15764                2366.0  ...                0       0         0         0
# 18776                1881.0  ...                0       0         0         0
# 8000                  744.0  ...                0       1         0         1
# 8374                 1100.0  ...                0       0         1         0
# 39319                 100.0  ...                0       0         0         0
# 16815                 679.0  ...                0       0         0         0
# 7805                  582.0  ...                0       0         0         1
# 23636               11092.0  ...                0       0         0         0
# 3591                    0.0  ...                0       0         0         0
# 39099                2112.0  ...                0       0         0         0
# 33753                1786.0  ...                0       0         1         0
# 29311                 960.0  ...                0       0         1         0
# 33421                 480.0  ...                0       0         0         0
# 39304                   0.0  ...                0       0         0         0
# 14034               43553.0  ...                0       1         0         1
# 28629                1820.0  ...                0       0         1         0
# 27992                2600.0  ...                0       0         0         1
# 6948                 2736.0  ...                0       0         0         0
# 46943                2352.0  ...                0       0         0         0
# 12111                2673.0  ...                0       0         1         0
# 8053                11286.0  ...                0       0         0         0
# 43112                 200.0  ...                0       0         1         0
# 23031                7896.0  ...                0       0         0         1
# 46956                8820.0  ...                0       0         0         0
# 7096                 1683.0  ...                0       0         0         0
# 16484                 300.0  ...                0       0         1         0
#
#        strict  super_strict_30  super_strict_60  log_price  prediction  \
# 46744       0                0                0   2.302585    5.774564
# 4425        0                0                0   2.302585    5.556149
# 49026       0                0                0   7.170120    4.107718
# 23352       1                0                0   7.313220    4.452875
# 16430       1                0                0   7.170120    4.327554
# 6981        1                0                0   2.302585    5.131991
# 48502       0                0                0   2.302585    4.889671
# 44734       0                0                0   2.302585    4.865316
# 11743       0                0                0   7.600402    5.104327
# 22632       0                0                0   6.551080    4.064511
# 25312       0                0                0   6.770789    4.318761
# 29699       0                0                0   2.302585    4.736843
# 1461        0                0                0   7.090077    4.691062
# 27576       0                0                0   6.907755    4.532935
# 46085       0                0                0   2.995732    5.269118
# 24832       0                0                0   7.313220    5.137779
# 40791       0                0                0   6.907755    4.767578
# 19755       0                0                0   2.302585    4.379866
# 8290        1                0                0   6.487684    4.430483
# 16991       0                0                0   6.775366    4.722660
# 26731       0                0                0   3.912023    5.944412
# 20656       0                0                0   6.395262    4.368976
# 30272       0                0                0   6.802395    4.916897
# 50532       0                0                0   3.912023    5.787139
# 34226       0                0                0   2.302585    4.176785
# 40593       1                0                0   3.912023    5.734605
# 9484        1                0                0   6.214608    4.407599
# 874         1                0                0   6.684612    4.939213
# 2230        0                0                0   7.244228    5.519856
# 17372       1                0                0   6.907755    5.183736
# ...       ...              ...              ...        ...         ...
# 7666        0                0                0   4.744932    4.746027
# 17318       1                0                0   4.382027    4.380977
# 26328       0                0                0   4.077537    4.078562
# 1197        0                0                0   3.806662    3.807684
# 15764       1                0                0   4.234107    4.235116
# 18776       1                0                0   4.976734    4.977724
# 8000        0                0                0   4.317488    4.316498
# 8374        0                0                0   4.382027    4.383017
# 39319       1                0                0   4.007333    4.008275
# 16815       1                0                0   5.988961    5.989885
# 7805        0                0                0   5.010635    5.011530
# 23636       1                0                0   3.912023    3.912867
# 3591        1                0                0   4.859812    4.859017
# 39099       1                0                0   3.912023    3.912816
# 33753       0                0                0   5.521461    5.520691
# 29311       0                0                0   4.770685    4.770024
# 33421       1                0                0   4.382027    4.382682
# 39304       1                0                0   4.174387    4.173835
# 14034       0                0                0   4.787492    4.788011
# 28629       0                0                0   4.317488    4.317994
# 27992       0                0                0   4.682131    4.682588
# 6948        1                0                0   4.110874    4.111310
# 46943       1                0                0   4.174387    4.174803
# 12111       0                0                0   4.174387    4.174795
# 8053        1                0                0   4.553877    4.553599
# 43112       0                0                0   4.727388    4.727596
# 23031       0                0                0   4.248495    4.248347
# 46956       1                0                0   5.214936    5.214999
# 7096        1                0                0   5.010635    5.010682
# 16484       0                0                0   4.094345    4.094324
#
#        abs_error
# 46744   3.471979
# 4425    3.253564
# 49026   3.062402
# 23352   2.860345
# 16430   2.842566
# 6981    2.829406
# 48502   2.587086
# 44734   2.562731
# 11743   2.496075
# 22632   2.486570
# 25312   2.452028
# 29699   2.434258
# 1461    2.399015
# 27576   2.374820
# 46085   2.273386
# 24832   2.175442
# 40791   2.140177
# 19755   2.077281
# 8290    2.057201
# 16991   2.052706
# 26731   2.032389
# 20656   2.026286
# 30272   1.885498
# 50532   1.875116
# 34226   1.874199
# 40593   1.822582
# 9484    1.807009
# 874     1.745399
# 2230    1.724371
# 17372   1.724019
# ...          ...
# 7666    0.001095
# 17318   0.001050
# 26328   0.001024
# 1197    0.001022
# 15764   0.001009
# 18776   0.000990
# 8000    0.000990
# 8374    0.000990
# 39319   0.000942
# 16815   0.000923
# 7805    0.000895
# 23636   0.000844
# 3591    0.000795
# 39099   0.000793
# 33753   0.000770
# 29311   0.000660
# 33421   0.000656
# 39304   0.000552
# 14034   0.000520
# 28629   0.000506
# 27992   0.000457
# 6948    0.000436
# 46943   0.000416
# 12111   0.000408
# 8053    0.000278
# 43112   0.000208
# 23031   0.000148
# 46956   0.000063
# 7096    0.000046
# 16484   0.000020
#
# [10200 rows x 42 columns]

# %% [markdown]
# # Prepare submission

# %%
df_prediction = df_test[X_columns].fillna(0.0)
df_test['log_price'] = model.predict(df_prediction)
df_test[['id', 'log_price']]
# Out:
#              id  log_price
# 0        986942   4.183918
# 1      16436737   4.367938
# 2      18209634   3.969700
# 3      15027024   4.275080
# 4      18074243   5.065389
# 5       8446914   5.305949
# 6      19362916   4.425259
# 7      16116059   6.076352
# 8      20912583   4.901763
# 9      13573101   4.880482
# 10     15938749   4.907280
# 11     13659214   4.015562
# 12      6239753   4.596588
# 13     11627400   5.453452
# 14     17794295   5.010913
# 15     15267276   4.982295
# 16      9476370   5.204405
# 17     14694999   5.091826
# 18     19847012   5.393514
# 19      8860277   4.790538
# 20      2975445   5.590895
# 21      1390712   4.965803
# 22     16144412   4.182881
# 23      1312673   4.998247
# 24      6645473   5.056031
# 25      7227023   5.205885
# 26     17283456   4.628968
# 27     13719227   4.944874
# 28     11413078   3.966766
# 29     15166399   4.574806
# ...         ...        ...
# 23081    840797   6.227952
# 23082   4880277   3.943103
# 23083  12816576   4.505357
# 23084  11626561   4.734509
# 23085  10051649   4.112327
# 23086  18406772   6.357322
# 23087   8776928   4.097632
# 23088   2811061   4.611035
# 23089  14606464   4.137070
# 23090   8564722   5.516699
# 23091    808919   4.367453
# 23092  10035324   4.524017
# 23093   1480015   6.095980
# 23094   8847624   5.277723
# 23095  18618632   4.206846
# 23096   6425382   4.962554
# 23097   7674543   4.619637
# 23098  12585689   6.125974
# 23099  17299278   4.044953
# 23100  18210259   4.673177
# 23101   1226155   4.257055
# 23102  16930596   4.721645
# 23103  10679702   4.647106
# 23104  13319386   4.224066
# 23105  18820769   5.919157
# 23106  15101498   4.247047
# 23107    298258   4.026001
# 23108   4917508   5.281426
# 23109  16645828   4.694100
# 23110  17797691   4.509380
#
# [23111 rows x 2 columns]

# %%
df_test[['id', 'log_price']].to_csv('submission_linear_regression.csv', index=False)
